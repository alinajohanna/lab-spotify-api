# %% [markdown]
# # Lab | Extending the internal databases with audio features
#
# At this point, you have the **hot_songs** and the **not_hot_songs** databases. However, you don't have any acoustic information about the songs.
# The purpose of this lab is to use Spotify's API to extend both databases with this information to use it later.
#
# ## Instructions
#
# * Create a function to search a given **single** song in the Spotify API: **search_song(title, artist, limit)**.
#
# First importing the necessary libraries.

# %%
import pandas as pd
import numpy as np

import sys

# getting the spotify credentials out of this file
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
# importing the previous created data frames with top 100 hot songs and top 2000 2023 "not hot" songs:

hot_songs = pd.read_csv('../../../Day_1/Morning/lab-web-scraping-single-page/billboard_top100.csv')
not_hot_songs = pd.read_csv('../../../Day_1/Afternoon/lab-not-hot-songs/not_hot_songs.csv')

# %%
hot_songs.drop(columns='Unnamed: 0', inplace=True)
not_hot_songs.drop(columns='Unnamed: 0', inplace=True)

# %%
hot_songs.head(3)
# Out:
#          artist                              title
# 0    Brenda Lee  Rockin' Around The Christmas Tree
# 1  Mariah Carey    All I Want For Christmas Is You
# 2   Bobby Helms                   Jingle Bell Rock

# %%
hot_songs['title'][0]
# Out:
# "Rockin' Around The Christmas Tree"

# %%
hot_songs['title'][0]+" "+hot_songs['artist'][0]
# Out:
# "Rockin' Around The Christmas Tree Brenda Lee"

# %%
results = sp.search(q=hot_songs['title'][0]+" "+hot_songs['artist'][0],limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Rockin%27+Around+The+Christmas+Tree+Brenda+Lee&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4cPHsZM98sKzmV26wlwD2W'},
#        'href': 'https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W',
#        'id': '4cPHsZM98sKzmV26wlwD2W',
#        'name': 'Brenda Lee',
#        'type': 'artist',
#        'uri': 'spotify:artist:4cPHsZM98sKzmV26wlwD2W'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34wa3zf2prXFMk47t9zHFG'},
#      'href': 'https://api.spotify.com/v1/albums/34wa3zf2prXFMk47t9zHFG',
#      'id': '34wa3zf2prXFMk47t9zHFG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737845f74d6db14b400fa61cd3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027845f74d6db14b400fa61cd3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517845f74d6db14b400fa61cd3',
#        'width': 64}],
#      'name': 'Merry Christmas From Brenda Lee',
#      'release_date': '1964-10-19',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:34wa3zf2prXFMk47t9zHFG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4cPHsZM98sKzmV26wlwD2W'},
#       'href': 'https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W',
#       'id': '4cPHsZM98sKzmV26wlwD2W',
#       'name': 'Brenda Lee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4cPHsZM98sKzmV26wlwD2W'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 126266,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC15848998'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2EjXfH91m7f8HiJN1yQg97'},
#     'href': 'https://api.spotify.com/v1/tracks/2EjXfH91m7f8HiJN1yQg97',
#     'id': '2EjXfH91m7f8HiJN1yQg97',
#     'is_local': False,
#     'name': "Rockin' Around The Christmas Tree",
#     'popularity': 98,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2EjXfH91m7f8HiJN1yQg97'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Rockin%27+Around+The+Christmas+Tree+Brenda+Lee&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
json_results = json.dumps(results, ensure_ascii=True)
json_results
# Out:
# '{"tracks": {"href": "https://api.spotify.com/v1/search?query=Rockin%27+Around+The+Christmas+Tree+Brenda+Lee&type=track&offset=0&limit=1", "items": [{"album": {"album_type": "album", "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/4cPHsZM98sKzmV26wlwD2W"}, "href": "https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W", "id": "4cPHsZM98sKzmV26wlwD2W", "name": "Brenda Lee", "type": "artist", "uri": "spotify:artist:4cPHsZM98sKzmV26wlwD2W"}], "available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NL", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "ZA", "SA", "AE", "BH", "QA", "OM", "KW", "EG", "MA", "DZ", "TN", "LB", "JO", "PS", "IN", "BY", "KZ", "MD", "UA", "AL", "BA", "HR", "ME", "MK", "RS", "SI", "KR", "BD", "PK", "LK", "GH", "KE", "NG", "TZ", "UG", "AG", "AM", "BS", "BB", "BZ", "BT", "BW", "BF", "CV", "CW", "DM", "FJ", "GM", "GE", "GD", "GW", "GY", "HT", "JM", "KI", "LS", "LR", "MW", "MV", "ML", "MH", "FM", "NA", "NR", "NE", "PW", "PG", "WS", "SM", "ST", "SN", "SC", "SL", "SB", "KN", "LC", "VC", "SR", "TL", "TO", "TT", "TV", "VU", "AZ", "BN", "BI", "KH", "CM", "TD", "KM", "GQ", "SZ", "GA", "GN", "KG", "LA", "MO", "MR", "MN", "NP", "RW", "TG", "UZ", "ZW", "BJ", "MG", "MU", "MZ", "AO", "CI", "DJ", "ZM", "CD", "CG", "IQ", "LY", "TJ", "VE", "ET", "XK"], "external_urls": {"spotify": "https://open.spotify.com/album/34wa3zf2prXFMk47t9zHFG"}, "href": "https://api.spotify.com/v1/albums/34wa3zf2prXFMk47t9zHFG", "id": "34wa3zf2prXFMk47t9zHFG", "images": [{"height": 640, "url": "https://i.scdn.co/image/ab67616d0000b2737845f74d6db14b400fa61cd3", "width": 640}, {"height": 300, "url": "https://i.scdn.co/image/ab67616d00001e027845f74d6db14b400fa61cd3", "width": 300}, {"height": 64, "url": "https://i.scdn.co/image/ab67616d000048517845f74d6db14b400fa61cd3", "width": 64}], "name": "Merry Christmas From Brenda Lee", "release_date": "1964-10-19", "release_date_precision": "day", "total_tracks": 12, "type": "album", "uri": "spotify:album:34wa3zf2prXFMk47t9zHFG"}, "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/4cPHsZM98sKzmV26wlwD2W"}, "href": "https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W", "id": "4cPHsZM98sKzmV26wlwD2W", "name": "Brenda Lee", "type": "artist", "uri": "spotify:artist:4cPHsZM98sKzmV26wlwD2W"}], "available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NL", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "ZA", "SA", "AE", "BH", "QA", "OM", "KW", "EG", "MA", "DZ", "TN", "LB", "JO", "PS", "IN", "BY", "KZ", "MD", "UA", "AL", "BA", "HR", "ME", "MK", "RS", "SI", "KR", "BD", "PK", "LK", "GH", "KE", "NG", "TZ", "UG", "AG", "AM", "BS", "BB", "BZ", "BT", "BW", "BF", "CV", "CW", "DM", "FJ", "GM", "GE", "GD", "GW", "GY", "HT", "JM", "KI", "LS", "LR", "MW", "MV", "ML", "MH", "FM", "NA", "NR", "NE", "PW", "PG", "WS", "SM", "ST", "SN", "SC", "SL", "SB", "KN", "LC", "VC", "SR", "TL", "TO", "TT", "TV", "VU", "AZ", "BN", "BI", "KH", "CM", "TD", "KM", "GQ", "SZ", "GA", "GN", "KG", "LA", "MO", "MR", "MN", "NP", "RW", "TG", "UZ", "ZW", "BJ", "MG", "MU", "MZ", "AO", "CI", "DJ", "ZM", "CD", "CG", "IQ", "LY", "TJ", "VE", "ET", "XK"], "disc_number": 1, "duration_ms": 126266, "explicit": false, "external_ids": {"isrc": "USMC15848998"}, "external_urls": {"spotify": "https://open.spotify.com/track/2EjXfH91m7f8HiJN1yQg97"}, "href": "https://api.spotify.com/v1/tracks/2EjXfH91m7f8HiJN1yQg97", "id": "2EjXfH91m ...

# %%
results['tracks']['items'][0]['id']
# Out:
# '2EjXfH91m7f8HiJN1yQg97'

# %%
def get_song_ids(df: pd.DataFrame):
    """
    Using spotipy.search to get IDs of songs stored in the df.
    
    The input df should contain a column with song 'title' and song 'artist'.
    
    Returns a list with the song IDs.
    """
    import time
    
    list_of_ids = []
    
    # define a chunk size
    chunk_size = 50
    
    for start in range(0, len(df), chunk_size):
        chunk = df[start:start+chunk_size]
        
        for index, row in chunk.iterrows():
            try:
                search_song = sp.search(q=row['title']+" "+row['artist'],limit=1)
                song_id = search_song['tracks']['items'][0]['id']
                list_of_ids.append(song_id)
            
            except:
                print("Song not found!")
                list_of_ids.append("")
                
        print(f"Processed {start+chunk_size} songs. Now sleeping a bit.")
        time.sleep(10)
        
    return list_of_ids

# %%
hot_song_id_list = get_song_ids(hot_songs)
# Out:
# Processed 50 songs. Now sleeping a bit.
# Processed 100 songs. Now sleeping a bit.

# %%
hot_song_id_list
# Out:
# ['2EjXfH91m7f8HiJN1yQg97',
#  '7iKRL1F3m4t4dkMponnD0P',
#  '7vQbuQcyTflfCIOu3Uzzya',
#  '2FRnf9qhLbvw8fu4IBXx78',
#  '77khP2fIVhSW23NwxrRluh',
#  '5hslUAKq9I9CG2bAulFkHN',
#  '2uFaJJtFpPDc5Pa95XzTvg',
#  '0oPdaY4dXtc3ZsaG17V972',
#  '4xhsWYTOGcal8zt0J161CU',
#  '5ASM6Qjiav2xPe7gRkQMsQ',
#  '0lizgQ7Qw35od7CYaoMBZb',
#  '4PS1e8f2LvuTFgUs1Cn3ON',
#  '3YZE5qDV7u1ZD1gZc47ZeR',
#  '5mM1jHHXhKc0ZYi0R8EOLn',
#  '46pF1zFimM582ss1PrMy68',
#  '4HEOgBHRCExyYVeTyrXsnL',
#  '1TH5fhztFZmUGWaCXmZ6ie',
#  '3QiAAp20rPC3dcAtKtMaqQ',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '1foCxQtxBweJtZmdxhEHVO',
#  '25leEEaz1gIpp7o21Fqyjo',
#  '2pnPe4pJtq7689i5ydzvJJ',
#  '5a1iz510sv2W9Dt1MvFd5R',
#  '3rUGC1vUpkDG9CZFHMur1t',
#  '75dfH68JDisE8dDaD4KlVY',
#  '1SV1fxF65n9NhRHp3KlBuu',
#  '2pXpURmn6zC5ZYDMms6fwa',
#  '3QIoEi8Enr9uHffwInGIsC',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '2QpN1ZVw8eJO5f7WcvUA1k',
#  '4KULAymBBJcPRpk1yO4dOG',
#  '5aIVCx5tnk0ntmdiinnYvw',
#  '4qP2V09IpTct5A1ZSnr1zh',
#  '38xhBO2AKrJnjdjVnhJES6',
#  '7dJYggqjKo71KI9sLzqCs8',
#  '59uQI0PADDKeE6UZDTJEe8',
#  '7xapw9Oy21WpfEcib2ErSA',
#  '3sDdyBHQ60Cs1opmIyRvhp',
#  '6NQchnlpozM5o4n6WfDznd',
#  '1OjmlSFuzYflWjSMTCyTJv',
#  '1DnSNqCQM3LUxqFuXt184Q',
#  '27RYrbL6S02LNVhDWVl38b',
#  '15sxLiiChE5dCW3Y756oas',
#  '0PAcdVzhPO4gq1Iym9ESnK',
#  '34MC0a5RRdXsfOEPAKiEd9',
#  '3bH2Eu9A9ymI4UnGHRmoXg',
#  '1Lo0QY9cvc8sUB2vnIOxDT',
#  '6usohdchdzW9oML7VC4Uhk',
#  '1Iq8oo9XkmmvCQiGOfORiz',
#  '2GapxG7BxK55ihQRAlR39e',
#  '0cVyQfDyRnMJ0V3rjjdlU3',
#  '5w0KPYIa7DUpstlDL7vLts',
#  '1a73gcEg6h6Re6hHXoVltJ',
#  '0mflMxspEfB0VbI1kyLiAv',
#  '5ZJGv7aGdIr9IGpxzSG18T',
#  '7MSWxMumjz6lHj7oRApNbg',
#  '759fzpnRkH3yjHsqBsXwKK',
#  '41WQUSINanQHfhfKpFDsms',
#  '4OMJGnvZfDvsePyCwRGO7X',
#  '0J1YRLYhTG1MBosjidD7OI',
#  '5ya0TmUQw2wHMkq36rPsnd',
#  '0R6NfOiLzLj4O5VbYSJAjf',
#  '2gT2iF1YK5r54A2PDEXVv8',
#  '7DswEZZthZ6piQpL25qGAM',
#  '3vkCueOmm7xQDoJ17W1Pm3',
#  '0HD8mbiPjp3o94X3EaZp0o',
#  '1udwFobQ1JoOdWPQrp2b6u',
#  '3lakwaXamzbachjLgrUegf',
#  '5mjYQaktjmjcMKcUIcqz4s',
#  '5Se32hEA9raeboZerywxka',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '2uvBprdlMpzeN5Bq0PzMBI',
#  '6CvTEtGagmzQvkUzzyKR9k',
#  '2kE2HFBFkJ0VMw3igxYohz',
#  '05WVKTdZhlIMX4qqMLuo0f',
#  '103u49mLoJUge83B1CnLxI',
#  '7hZTywPKMdVjJzwdWu11BK',
#  '6gmY1F2AMw2i4gO79ppBAe',
#  '5XVdHRf4CAJ2Jm0uMIy5qY',
#  '0eBFgRxyVSeuT4iyrbukdn',
#  '5qo0wgdoWODZj9efbNWgv0',
#  '3CWq0pAKKTWb0K4yiglDc4',
#  '1xWkeSPhf3bZqHY7Ncz8vp',
#  '6UoKX6uLJwhsnyTp5k5StP',
#  '6uTPdRrEDeH8Fyg5L5qmeU',
#  '09hVlIVHtEE1nLUv6YGZiW',
#  '0u1Sp4e3Phbbg9U215CMBe',
#  '6fNCrsrdIcgVd2aZZ0nnz4',
#  '4I4G0LD277PWvfblYtSf91',
#  '2ljUUoqlnRUGGa7bmpvevC',
#  '7rr3gguU3TcVnLZD9VzASE',
#  '4qmG24ebshLXtKu9HIShBP',
#  '4pCbJC43j3gSqG6Fen6upD',
#  '2Zo1PcszsT9WQ0ANntJbID',
#  '56xHMIfQPoe0prrSi3BGhf',
#  '0O3U5iwTbiXCREMkvotJuN',
#  '2KslE17cAJNHTsI2MI0jb2',
#  '73zawW1ttszLRgT9By826D',
#  '2Sy3dDqPwjnTO3PnommJPe',
#  '4M68xjcc42oxyphhzpOWXS']

# %% [markdown]
# Once the desired song is located, **the function should return the href/id/uri of the song to the code** (not to the user) to get the audio features.
#
# * Create a function **get_audio_features(list_of_song_ids)** to obtain the audio features of a given list of songs (the content of list_of_songs can be the href/id/uri or a list with a single song IDs).

# %%
#testing the function audio_features
sp.audio_features(['0cVyQfDyRnMJ0V3rjjdlU3'])
# Out:
# [{'danceability': 0.85,
#   'energy': 0.699,
#   'key': 0,
#   'loudness': -3.292,
#   'mode': 1,
#   'speechiness': 0.0776,
#   'acousticness': 0.152,
#   'instrumentalness': 0,
#   'liveness': 0.32,
#   'valence': 0.915,
#   'tempo': 114.481,
#   'type': 'audio_features',
#   'id': '0cVyQfDyRnMJ0V3rjjdlU3',
#   'uri': 'spotify:track:0cVyQfDyRnMJ0V3rjjdlU3',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cVyQfDyRnMJ0V3rjjdlU3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cVyQfDyRnMJ0V3rjjdlU3',
#   'duration_ms': 114234,
#   'time_signature': 4}]

# %%
def get_audio_features(list_of_song_ids: list):
    """
    Using the song IDs stored in a list to get the audio features out of the Spotify Database.
    Performs a bulk request of 50 IDs at once to retrieve the audio features.
    Returns a dataframe with the corresponding audio features.
    """
    
    import time 
    
    #feature_list = []
    feature_df = pd.DataFrame()

    # define a chunk size
    chunk_size = 50
    
    for start in range(0, len(list_of_song_ids), chunk_size):
        #for start in range(0,100,50) -> chunk_size is the increment. second loop will start from chunk_size
        try:
            features = sp.audio_features(tracks=list_of_song_ids[start:start+chunk_size])
            #features = sp.audio_features(tracks='id1, id2, ..., id49')
        
            for f in features:
                df_temp = pd.DataFrame([f])
                feature_df = pd.concat([feature_df, df_temp], ignore_index=True)
        
        except:
            print(f"Error processing tracks in {start:start+chunk_size}")

    print(f"Processed {start+chunk_size} songs. Now sleeping a bit.")
    time.sleep(10)
    
    return feature_df

# %%
#def get_audio_features(list_of_song_ids: list):
#    """
#    Using the song IDs to get the audio features out of the Spotify Database.
   """
    
    import time 
    
    feature_list = []
    
    # First, we are creating chunks:
    chunk_size = 50
    
    for start in range(0, len(list_of_song_ids), chunk_size):
        chunk = list_of_song_ids[start:start+chunk_size]
        
        for i in chunk:
            try:
                my_dict = sp.audio_features([i])[0]
                #my_dict_new = {key : [my_dict[key]] for key in my_dict.keys()}
                feature_list.append(my_dict)
                
            except:
                print("Error retrieving features for song:", i)
    
        print("Sleeping a bit before getting the next ids")
        time.sleep(30)
        
    feature_df = pd.DataFrame(feature_list)
    
    return feature_df

# %%
hot_song_feature_df = get_audio_features(hot_song_id_list)
# Out:
# Processed 100 songs. Now sleeping a bit.

# %%
hot_song_feature_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.589   0.472    8    -8.749     1       0.0502       0.61400
# 1          0.548   0.871    7    -4.253     1       0.0708       0.00113
# 2          0.754   0.424    2    -8.463     1       0.0363       0.64300
# 3          0.735   0.478    2   -12.472     1       0.0293       0.18900
# 4          0.683   0.375    0   -13.056     1       0.0303       0.57900
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.616   0.834    9    -3.069     1       0.0664       0.06000
# 96         0.711   0.809    2    -4.389     0       0.0955       0.04470
# 97         0.498   0.764    4    -5.006     1       0.0309       0.12300
# 98         0.844   0.637   10    -6.072     0       0.0325       0.22000
# 99         0.670   0.555    1    -9.120     0       0.0908       0.03820
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.5050    0.898   67.196  audio_features
# 1           0.000000    0.7650    0.640  128.136  audio_features
# 2           0.000000    0.0652    0.806  119.705  audio_features
# 3           0.000002    0.3550    0.947  107.682  audio_features
# 4           0.000000    0.0760    0.888  140.467  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.3380    0.746  151.701  audio_features
# 96          0.000000    0.3390    0.816  106.017  audio_features
# 97          0.000031    0.1190    0.489  147.984  audio_features
# 98          0.000000    0.0459    0.960  125.012  audio_features
# 99          0.000006    0.4140    0.160  156.937  audio_features
#
#                         id                                   uri  \
# 0   2EjXfH91m7f8HiJN1yQg97  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 1   7iKRL1F3m4t4dkMponnD0P  spotify:track:7iKRL1F3m4t4dkMponnD0P
# 2   7vQbuQcyTflfCIOu3Uzzya  spotify:track:7vQbuQcyTflfCIOu3Uzzya
# 3   2FRnf9qhLbvw8fu4IBXx78  spotify:track:2FRnf9qhLbvw8fu4IBXx78
# 4   77khP2fIVhSW23NwxrRluh  spotify:track:77khP2fIVhSW23NwxrRluh
# ..                     ...                                   ...
# 95  0O3U5iwTbiXCREMkvotJuN  spotify:track:0O3U5iwTbiXCREMkvotJuN
# 96  2KslE17cAJNHTsI2MI0jb2  spotify:track:2KslE17cAJNHTsI2MI0jb2
# 97  73zawW1ttszLRgT9By826D  spotify:track:73zawW1ttszLRgT9By826D
# 98  2Sy3dDqPwjnTO3PnommJPe  spotify:track:2Sy3dDqPwjnTO3PnommJPe
# 99  4M68xjcc42oxyphhzpOWXS  spotify:track:4M68xjcc42oxyphhzpOWXS
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2EjXfH91m7f8...
# 1   https://api.spotify.com/v1/tracks/7iKRL1F3m4t4...
# 2   https://api.spotify.com/v1/tracks/7vQbuQcyTflf...
# 3   https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# 4   https://api.spotify.com/v1/tracks/77khP2fIVhSW...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/0O3U5iwTbiXC...
# 96  https://api.spotify.com/v1/tracks/2KslE17cAJNH...
# 97  https://api.spotify.com/v1/tracks/73zawW1ttszL...
# 98  https://api.spotify.com/v1/tracks/2Sy3dDqPwjnT...
# 99  https://api.spotify.com/v1/tracks/4M68xjcc42ox...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2EjX...       126267
# 1   https://api.spotify.com/v1/audio-analysis/7iKR...       215653
# 2   https://api.spotify.com/v1/audio-analysis/7vQb...       130973
# 3   https://api.spotify.com/v1/audio-analysis/2FRn...       262960
# 4   https://api.spotify.com/v1/audio-analysis/77kh...       135533
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/0O3U...       165848
# 96  https://api.spotify.com/v1/audio-analysis/2Ksl...       206020
# 97  https://api.spotify.com/v1/audio-analysis/73za...       191231
# 98  https://api.spotify.com/v1/audio-analysis/2Sy3...       189426
# 99  https://api.spotify.com/v1/audio-analysis/4M68...       146808
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               3
# 99               4
#
# [100 rows x 18 columns]

# %% [markdown]
# * Once the previous function has been created, create another function **add_audio_features(df, audio_features_df)** to concat a given dataframe with the audio features dataframe and return the extended data frame.

# %%
def add_audio_features(df, audio_features_df):
    """
    Concats a given dataframe with the audio features dataframe and return the extended data frame. 
    """
    
    final_df = pd.concat([df, audio_features_df], axis=1)
    
    return final_df

# %%
final_hot_songs = add_audio_features(hot_songs, hot_song_feature_df)

# %%
final_hot_songs.head()
# Out:
#          artist                              title  danceability  energy  key  \
# 0    Brenda Lee  Rockin' Around The Christmas Tree         0.589   0.472    8
# 1  Mariah Carey    All I Want For Christmas Is You         0.548   0.871    7
# 2   Bobby Helms                   Jingle Bell Rock         0.754   0.424    2
# 3         Wham!                     Last Christmas         0.735   0.478    2
# 4     Burl Ives            A Holly Jolly Christmas         0.683   0.375    0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -8.749     1       0.0502       0.61400          0.000000    0.5050
# 1    -4.253     1       0.0708       0.00113          0.000000    0.7650
# 2    -8.463     1       0.0363       0.64300          0.000000    0.0652
# 3   -12.472     1       0.0293       0.18900          0.000002    0.3550
# 4   -13.056     1       0.0303       0.57900          0.000000    0.0760
#
#    valence    tempo            type                      id  \
# 0    0.898   67.196  audio_features  2EjXfH91m7f8HiJN1yQg97
# 1    0.640  128.136  audio_features  7iKRL1F3m4t4dkMponnD0P
# 2    0.806  119.705  audio_features  7vQbuQcyTflfCIOu3Uzzya
# 3    0.947  107.682  audio_features  2FRnf9qhLbvw8fu4IBXx78
# 4    0.888  140.467  audio_features  77khP2fIVhSW23NwxrRluh
#
#                                     uri  \
# 0  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 1  spotify:track:7iKRL1F3m4t4dkMponnD0P
# 2  spotify:track:7vQbuQcyTflfCIOu3Uzzya
# 3  spotify:track:2FRnf9qhLbvw8fu4IBXx78
# 4  spotify:track:77khP2fIVhSW23NwxrRluh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2EjXfH91m7f8...
# 1  https://api.spotify.com/v1/tracks/7iKRL1F3m4t4...
# 2  https://api.spotify.com/v1/tracks/7vQbuQcyTflf...
# 3  https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# 4  https://api.spotify.com/v1/tracks/77khP2fIVhSW...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2EjX...       126267
# 1  https://api.spotify.com/v1/audio-analysis/7iKR...       215653
# 2  https://api.spotify.com/v1/audio-analysis/7vQb...       130973
# 3  https://api.spotify.com/v1/audio-analysis/2FRn...       262960
# 4  https://api.spotify.com/v1/audio-analysis/77kh...       135533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
not_hot_song_id_list = get_song_ids(not_hot_songs)
# Out:
# Processed 50 songs. Now sleeping a bit.
# Processed 100 songs. Now sleeping a bit.
# Processed 150 songs. Now sleeping a bit.
# Processed 200 songs. Now sleeping a bit.
# Processed 250 songs. Now sleeping a bit.
# Processed 300 songs. Now sleeping a bit.
# Processed 350 songs. Now sleeping a bit.
# Processed 400 songs. Now sleeping a bit.
# Processed 450 songs. Now sleeping a bit.
# Processed 500 songs. Now sleeping a bit.
# Processed 550 songs. Now sleeping a bit.
# Processed 600 songs. Now sleeping a bit.
# Processed 650 songs. Now sleeping a bit.
# Processed 700 songs. Now sleeping a bit.
# Processed 750 songs. Now sleeping a bit.
# Processed 800 songs. Now sleeping a bit.
# Processed 850 songs. Now sleeping a bit.
# Processed 900 songs. Now sleeping a bit.
# Processed 950 songs. Now sleeping a bit.
# Processed 1000 songs. Now sleeping a bit.
# Processed 1050 songs. Now sleeping a bit.
# Processed 1100 songs. Now sleeping a bit.
# Processed 1150 songs. Now sleeping a bit.
# Processed 1200 songs. Now sleeping a bit.
# Processed 1250 songs. Now sleeping a bit.
# Processed 1300 songs. Now sleeping a bit.
# Processed 1350 songs. Now sleeping a bit.
# Processed 1400 songs. Now sleeping a bit.
# Processed 1450 songs. Now sleeping a bit.
# Processed 1500 songs. Now sleeping a bit.
# Processed 1550 songs. Now sleeping a bit.
# Processed 1600 songs. Now sleeping a bit.
# Processed 1650 songs. Now sleeping a bit.
# Processed 1700 songs. Now sleeping a bit.
# Processed 1750 songs. Now sleeping a bit.
# Processed 1800 songs. Now sleeping a bit.
# Processed 1850 songs. Now sleeping a bit.
# Processed 1900 songs. Now sleeping a bit.
# Processed 1950 songs. Now sleeping a bit.
# Processed 2000 songs. Now sleeping a bit.

# %%
len(not_hot_song_id_list)
# Out:
# 1995

# %%
not_hot_song_feature_df = get_audio_features(not_hot_song_id_list)
# Out:
# Processed 2000 songs. Now sleeping a bit.

# %%
not_hot_song_feature_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.397   0.386    0   -10.405     0       0.0503       0.27100
# 1            0.401   0.383    9   -10.048     1       0.0279       0.51000
# 2            0.579   0.508    2    -9.484     1       0.0270       0.00574
# 3            0.331   0.550    0    -6.483     1       0.0272       0.60500
# 4            0.209   0.417    3    -8.740     1       0.0338       0.16400
# ...            ...     ...  ...       ...   ...          ...           ...
# 1990         0.877   0.422   10   -14.933     0       0.0546       0.04000
# 1991         0.581   0.654    0    -7.428     1       0.0249       0.18800
# 1992         0.419   0.383    4   -11.782     1       0.0256       0.07240
# 1993         0.870   0.706    1    -5.769     1       0.0417       0.56000
# 1994         0.551   0.289    8   -12.214     0       0.0262       0.33400
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1880    0.210  144.242  audio_features
# 1             0.007800    0.1210    0.285   96.957  audio_features
# 2             0.000494    0.0575    0.609  147.125  audio_features
# 3             0.000004    0.1920    0.429  177.734  audio_features
# 4             0.001960    0.1130    0.124  138.178  audio_features
# ...                ...       ...      ...      ...             ...
# 1990          0.000406    0.1820    0.970  131.103  audio_features
# 1991          0.000461    0.2690    0.620  104.996  audio_features
# 1992          0.017600    0.0896    0.350   87.568  audio_features
# 1993          0.000000    0.1040    0.953  122.980  audio_features
# 1994          0.000000    0.0379    0.117  132.133  audio_features
#
#                           id                                   uri  \
# 0     6l8GvAyoUZwWDgF1e4822w  spotify:track:6l8GvAyoUZwWDgF1e4822w
# 1     5B5YKjgne3TZzNpMsN9aj1  spotify:track:5B5YKjgne3TZzNpMsN9aj1
# 2     40riOy7x9W7GXjyGp4pjAv  spotify:track:40riOy7x9W7GXjyGp4pjAv
# 3     70C4NyhjD5OZUMzvWZ3njJ  spotify:track:70C4NyhjD5OZUMzvWZ3njJ
# 4     7LVHVU3tWfcxj5aiPFEW4Q  spotify:track:7LVHVU3tWfcxj5aiPFEW4Q
# ...                      ...                                   ...
# 1990  5EAgXGJ8Kw5QAfhQkZXYqT  spotify:track:5EAgXGJ8Kw5QAfhQkZXYqT
# 1991  66RRhWLXx7OvJidJvhs7AE  spotify:track:66RRhWLXx7OvJidJvhs7AE
# 1992  2a1iMaoWQ5MnvLFBDv4qkf  spotify:track:2a1iMaoWQ5MnvLFBDv4qkf
# 1993  7nuBU1HCcOwG5f1orN4ByW  spotify:track:7nuBU1HCcOwG5f1orN4ByW
# 1994  2jxqu3v4AZAhUNvdAbDGet  spotify:track:2jxqu3v4AZAhUNvdAbDGet
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6l8GvAyoUZwW...
# 1     https://api.spotify.com/v1/tracks/5B5YKjgne3TZ...
# 2     https://api.spotify.com/v1/tracks/40riOy7x9W7G...
# 3     https://api.spotify.com/v1/tracks/70C4NyhjD5OZ...
# 4     https://api.spotify.com/v1/tracks/7LVHVU3tWfcx...
# ...                                                 ...
# 1990  https://api.spotify.com/v1/tracks/5EAgXGJ8Kw5Q...
# 1991  https://api.spotify.com/v1/tracks/66RRhWLXx7Ov...
# 1992  https://api.spotify.com/v1/tracks/2a1iMaoWQ5Mn...
# 1993  https://api.spotify.com/v1/tracks/7nuBU1HCcOwG...
# 1994  https://api.spotify.com/v1/tracks/2jxqu3v4AZAh...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6l8G...       355400
# 1     https://api.spotify.com/v1/audio-analysis/5B5Y...       269986
# 2     https://api.spotify.com/v1/audio-analysis/40ri...       391376
# 3     https://api.spotify.com/v1/audio-analysis/70C4...       339000
# 4     https://api.spotify.com/v1/audio-analysis/7LVH...       295533
# ...                                                 ...          ...
# 1990  https://api.spotify.com/v1/audio-analysis/5EAg...       307933
# 1991  https://api.spotify.com/v1/audio-analysis/66RR...       173400
# 1992  https://api.spotify.com/v1/audio-analysis/2a1i...       257480
# 1993  https://api.spotify.com/v1/audio-analysis/7nuB...       225932
# 1994  https://api.spotify.com/v1/audio-analysis/2jxq...       395400
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  3
# 4                  4
# ...              ...
# 1990               4
# 1991               4
# 1992               4
# 1993               4
# 1994               4
#
# [1995 rows x 18 columns]

# %%
final_not_hot_songs = add_audio_features(not_hot_songs, not_hot_song_feature_df)

# %%
final_hot_songs.to_csv('hot_songs.csv')
final_not_hot_songs.to_csv('not_hot_songs.csv')

# %%
function_file = 'my_function.py'  
with open(function_file, 'a') as file:
    file.write(
    '''
    def get_song_ids(df: pd.DataFrame):
    """
    Using spotipy.search to get IDs of songs stored in the df.
    
    The input df should contain a column with song 'title' and song 'artist'.
    
    Returns a list with the song IDs.
    """
    import time
    
    list_of_ids = []
    
    # define a chunk size
    chunk_size = 50
    
    for start in range(0, len(df), chunk_size):
        chunk = df[start:start+chunk_size]
        
        for index, row in chunk.iterrows():
            try:
                search_song = sp.search(q=row['title']+" "+row['artist'],limit=1)
                song_id = search_song['tracks']['items'][0]['id']
                list_of_ids.append(song_id)
            
            except:
                print("Song not found!")
                list_of_ids.append("")
                
        print(f"Processed {start+chunk_size} songs. Now sleeping a bit.")
        time.sleep(10)
        
    return list_of_ids
    
    
    
    def get_audio_features(list_of_song_ids: list):
    """
    Using the song IDs stored in a list to get the audio features out of the Spotify Database.
    Performs a bulk request of 50 IDs at once to retrieve the audio features.
    Returns a dataframe with the corresponding audio features.
    """
    
    import time 
    
    #feature_list = []
    feature_df = pd.DataFrame()

    # define a chunk size
    chunk_size = 50
    
    for start in range(0, len(list_of_song_ids), chunk_size):
        #for start in range(0,100,50) -> chunk_size is the increment. second loop will start from chunk_size
        try:
            features = sp.audio_features(tracks=list_of_song_ids[start:start+chunk_size])
            #features = sp.audio_features(tracks='id1, id2, ..., id49')
        
            for f in features:
                df_temp = pd.DataFrame([f])
                feature_df = pd.concat([feature_df, df_temp], ignore_index=True)
        
        except:
            print(f"Error processing tracks in {start:start+chunk_size}")

    print(f"Processed {start+chunk_size} songs. Now sleeping a bit.")
    time.sleep(10)
    
    return feature_df
    
    
    
    def add_audio_features(df, audio_features_df):
    """
    Concats a given dataframe with the audio features dataframe and return the extended data frame. 
    """
    
    final_df = pd.concat([df, audio_features_df], axis=1)
    
    return final_df
    ''')
